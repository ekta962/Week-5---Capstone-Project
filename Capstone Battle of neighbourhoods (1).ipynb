# %% [markdown]
# # Capstone Project- The Battle of Neigbourhoods

# %% [markdown]
# # Table of contents
#
# * Introduction
# * Data
# * Methodolgy
# * Analysis
# * Results and Discussion
# * Conclusion

# %% [markdown]
# ## Introduction
#
# Being a Indian and Love for the Indian food allover the world is amazing but availability of Indian food and taste is not easy to find.
#
# Switzerland is one of the famous tourist place and one of the favourite place for the Indians but the Availability of Indian food is not that much even if the location is in Downtown.
#
# This Project will help us to find the location in switzerland (Zurich) and its nearby areas where Asian food can be available as Indian Food specifically will narrow our search.
#
# Prior launching any restaurant, it’s important to know if the business as a good opportunity. In order to do so, this report will try to gather data about other restaurant localization, competitors and best localization.
#
# These data could be use for a business plan afterward
#
# ## Problem
#
# As the goal of this is to create a business plan in the end, we need to make sure data from api are correct. We also need to check that customer could be interested in this specific business.
#
# In order to do so, a survey in Zurich will be done in addition to data gathering. I’ll go in the cities and check at different hours if restaurants are working, if streets are full and so on, and what kind of restaurant works well. This survey will allow to validate the data analysis done here.
#
# ## Interest
# This study can be used by anyone interested by opening a restaurant. Or any other business.
#
# Maybe they will need to modify some data.

# %% [markdown]
# ## Data
#
# The idea of doing the project and data collection is taken from one of the tempalte shared in coursera project. I will keep the idea of clustering the city by area and then plot heatmap to find better area.
#
# I will change some data:
#
# Country/City: Switzerland
# Goal: Open a restaurant/little shop for workers in weekday and maybe saturday
# So, I will cross data from working days, and localisations.
#
# I will use the following API:
#
# Foursquare API: to find restaurant/venues
# Google API: reverse geolocalisation
#
# ## Neighborhood Candidates
#
# Firstly, we will  create latitude & longitude coordinates for centroids of our candidate neighborhoods. We will be create a grid of cells covering our area of interest which is aprox. 1.5km killometers centered around Zurich city center.
#
# Let's first find the latitude & longitude of Zurich city center, using specific, well known address and Google Maps geocoding API.
#
# We'll consider the Prefecture to be the city center, as a lot of companies are around

# %% [markdown]
# ### Importing all the librarires and paswrds

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !pip install shapely
import shapely.geometry

# !pip install pyproj
import pyproj

import math
import warnings

! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Requirement already satisfied: geopy in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (2.1.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geopy) (1.50)
# Requirement already satisfied: shapely in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (1.7.1)
# Requirement already satisfied: pyproj in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (1.9.6)
# Requirement already satisfied: folium==0.5.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.5.0)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (2.25.1)
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: branca in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (0.4.2)
# Requirement already satisfied: jinja2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (2.11.3)
# Requirement already satisfied: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (4.0.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Folium installed
# Libraries imported.

# %% [markdown]
# #### Let's assume that we are staying at the Zurich downtown (Central Plaza). So let's start by converting the Central Plaza address to its latitude and longitude coordinates.

# %%
address = 'Central 1, 8001 Zurich'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 47.3770836 8.543634

# %% [markdown]
# Now let's create a grid of area candidates, equaly spaced, centered around city center and within ~1.5km from Prefecture. Our neighborhoods will be defined as circular areas with a radius of 100 meters, so our neighborhood centers will be 200 meters apart.
#
# To accurately calculate distances we need to create our grid of locations in Cartesian 2D coordinate system which allows us to calculate distances in meters (not in latitude/longitude degrees). Then we'll project those coordinates back to latitude/longitude degrees to be shown on Folium map

# %%
search_query = 'Asian food'
radius = 5000
print(search_query + ' .... OK!')
# Out:
# Asian food .... OK!

# %%
CLIENT_ID = 'M0XKWEK2RJZSE5XJIH0MPUBZPWZ2UGFUEGK5YCO1HGVGNGSU' # your Foursquare ID
CLIENT_SECRET = 'YMYYBKNJXFSPZ5XX1BMHJIZC0IDKVDYHFLODBWVHHCJALL5F' # your Foursquare Secret
ACCESS_TOKEN = 'DNGKZPAWP3VZZTOT0LXWDZGEEQXRQJZIJ0TU0NKOUBMOVLWD' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 40
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=M0XKWEK2RJZSE5XJIH0MPUBZPWZ2UGFUEGK5YCO1HGVGNGSU&client_secret=YMYYBKNJXFSPZ5XX1BMHJIZC0IDKVDYHFLODBWVHHCJALL5F&ll=47.3770836,8.543634&oauth_token=DNGKZPAWP3VZZTOT0LXWDZGEEQXRQJZIJ0TU0NKOUBMOVLWD&v=20180604&query=Asian food&radius=5000&limit=40'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '609aecdbd4b5bd6922bb30e8'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'venues': [{'id': '4e5407058877863330aa8874',
#     'name': 'Asian Sport Center',
#     'location': {'lat': 47.3826760023631,
#      'lng': 8.547707985902278,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.3826760023631,
#        'lng': 8.547707985902278}],
#      'distance': 694,
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d1b2941735',
#       'name': 'College Gym',
#       'pluralName': 'College Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '4ec4eefbf790c16e5225be61',
#     'name': 'Fo Ke Kio Asian Take Away',
#     'location': {'address': 'Talacker 50A',
#      'lat': 47.37214184335466,
#      'lng': 8.534840510608197,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.37214184335466,
#        'lng': 8.534840510608197}],
#      'distance': 861,
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Talacker 50A', 'Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '52013213498e9178ab9e16af',
#     'name': 'Little Nooch Asian Streetfood',
#     'location': {'address': 'Hofwiesenstr. 369',
#      'crossStreet': 'Bahnhof Oerlikon',
#      'lat': 47.41123460919642,
#      'lng': 8.543782532215117,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.41123460919642,
#        'lng': 8.543782532215117}],
#      'distance': 3801,
#      'postalCode': '8050',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Hofwiesenstr. 369 (Bahnhof Oerlikon)',
#       '8050 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '5193c15b498ec560cd705c47',
#     'name': 'Asian-Wellness',
#     'location': {'address': 'Schaffhauserstrasse 43',
#      'lat': 47.391070156967274,
#      'lng': 8.538932801476742,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.391070156967274,
#        'lng': 8.538932801476742}],
#      'distance': 1596,
#      'postalCode': '8037',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Schaffhauserstrasse 43', '8037 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d1ed941735',
#       'name': 'Spa',
#       'pluralName': 'Spas',
#       'shortName': 'Spa',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '4bf6cf4b4a67c9282a7322cf',
#     'name': 'Asian Moon',
#     'location': {'address': 'Seefeldstrasse 40',
#      'crossStreet': 'at Kreuzstrasse',
#      'lat': 47.36304278640203,
#      'lng': 8.549530841903215,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.36304278640203,
#        'lng': 8.549530841903215}],
#      'distance': 1625,
#      'postalCode': '8008',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Seefeldstrasse 40 (at Kreuzstrasse)',
#       '8008 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '4f5bb376e4b0090c09cda75b',
#     'name': "YEN'S Sushi & Asian Cuisine",
#     'location': {'address': 'Hallwylerstr. 43',
#      'lat': 47.37136901098179,
#      'lng': 8.528703527634999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.37136901098179,
#        'lng': 8.528703527634999}],
#      'distance': 1292,
#      'postalCode': '8004',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Hallwylerstr. 43', '8004 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '5e0b4830456d3b000815955b',
#     'name': 'Viet Street Food',
#     'location': {'address': 'Usteristrasse 21',
#      'lat': 47.376122,
#      'lng': 8.536371,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.376122,
#        'lng': 8.536371}],
#      'distance': 557,
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Usteristrasse 21', 'Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '4b59ca7af964a520369828e3',
#     'name': 'India Street-Food',
#     'location': {'address': 'Langstrasse 213',
#      'lat': 47.383168,
#      'lng': 8.530197,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.383168,
#        'lng': 8.530197}],
#      'distance': 1218,
#      'postalCode': '8005',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Langstrasse 213', '8005 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '5bac7c428b98fd0039448a15',
#     'name': 'Food Station',
#     'location': {'address': 'Bahnhofplatz 15',
#      'lat': 47.378204,
#      'lng': 8.535982,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.378204,
#        'lng': 8.535982}],
#      'distance': 590,
#      'cc': 'CH',
#      'country': 'Schweiz',
#      'formattedAddress': ['Bahnhofplatz 15']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '595a8086c365882ea49c863c',
#     'name': 'Asianart',
#     'location': {'address': 'Schreinerstrasse 64',
#      'lat': 47.37708,
#      'lng': 8.523304,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.37708,
#        'lng': 8.523304}],
#      'distance': 1532,
#      'postalCode': '8004',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Schreinerstrasse 64', '8004 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '4f8d5903e4b0e5ed77fe6a91',
#     'name': 'Thai Food Corner GmbH',
#     'location': {'lat': 47.37932922752695,
#      'lng': 8.535520349101649,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.37932922752695,
#        'lng': 8.535520349101649}],
#      'distance': 660,
#      'cc': 'CH',
#      'country': 'Schweiz'},
#     'categories': [],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '5cc1c6a4cabcff002ce22ad4',
#     'name': 'Coop Supermarkt City Zürich St. Annahof Food',
#     'location': {'address': 'Bahnhofstrasse 57',
#      'lat': 47.37290177,
#      'lng': 8.5380241,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.37290177,
#        'lng': 8.5380241}],
#      'distance': 628,
#      'postalCode': '8001',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Bahnhofstrasse 57', '8001 Zürich']},
#     'categories': [],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '4d43f0b9bf61a1cdc65c03ac',
#     'name': 'Asian Take-Away & Restaurant',
#     'location': {'address': 'Hofwiesenstrasse 376',
#      'lat': 47.411310560358935,
#      'lng': 8.54501065608432,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.411310560358935,
#        'lng': 8.54501065608432}],
#      'distance': 3811,
#      'postalCode': '8050',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Hofwiesenstrasse 376', '8050 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '4bf65f0f004ed13a494c42a0',
#     'name': 'Asian Park',
#     'location': {'address': 'Baslerstrasse 102',
#      'lat': 47.386635,
#      'lng': 8.49378,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.386635,
#        'lng': 8.49378}],
#      'distance': 3905,
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Baslerstrasse 102', 'Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d118951735',
#       'name': 'Grocery Store',
#       'pluralName': 'Grocery Stores',
#       'shortName': 'Grocery Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '4b5841fff964a520e24f28e3',
#     'name': 'food&lab',
#     'location': {'address': 'Rämistr. 101',
#      'lat': 47.378326832136075,
#      'lng': 8.548847647902788,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.378326832136075,
#        'lng': 8.548847647902788}],
#      'distance': 416,
#      'cc': 'CH',
#      'neighborhood': 'Oberstrass',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Rämistr. 101', 'Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d128941735',
#       'name': 'Cafeteria',
#       'pluralName': 'Cafeterias',
#       'shortName': 'Cafeteria',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '560595f7498eb0f06171956e',
#     'name': 'Food  from Farmers',
#     'location': {'address': 'Langstrasse 211',
#      'crossStreet': 'Josefstrasse',
#      'lat': 47.368501932208424,
#      'lng': 8.545671103929276,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.368501932208424,
#        'lng': 8.545671103929276}],
#      'distance': 967,
#      'postalCode': '8005',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Langstrasse 211 (Josefstrasse)', '8005 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d16c941735',
#       'name': 'Burger Joint',
#       'pluralName': 'Burger Joints',
#       'shortName': 'Burgers',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '4e87185182316be403a7f640',
#     'name': 'Hong-Kong Food Paradise',
#     'location': {'address': 'Seidengasse 1',
#      'lat': 47.374041690035696,
#      'lng': 8.536561591935998,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.374041690035696,
#        'lng': 8.536561591935998}],
#      'distance': 631,
#      'postalCode': '8001',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Seidengasse 1', '8001 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '4ccae8789b9346889f9e5141',
#     'name': 'Thai Food Corner',
#     'location': {'address': 'Brauerstrasse 3',
#      'lat': 47.376984,
#      'lng': 8.528394,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.376984,
#        'lng': 8.528394}],
#      'distance': 1148,
#      'postalCode': '8004',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Brauerstrasse 3', '8004 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '5cc1c8e44a1cc0002c7d8132',
#     'name': 'Coop Supermarkt City Zürich Bellevue Food',
#     'location': {'address': 'Theaterstrasse 18',
#      'lat': 47.367308,
#      'lng': 8.54607888,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.367308,
#        'lng': 8.54607888}],
#      'distance': 1103,
#      'postalCode': '8024',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Theaterstrasse 18', '8024 Zürich']},
#     'categories': [],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '5357cc16498e0e40db63f54a',
#     'name': 'Jelmoli Food Market',
#     'location': {'lat': 47.3740827107709,
#      'lng': 8.537229322704722,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.3740827107709,
#        'lng': 8.537229322704722}],
#      'distance': 587,
#      'cc': 'CH',
#      'country': 'Schweiz'},
#     'categories': [{'id': '50be8ee891d4fa8dcc7199a7',
#       'name': 'Market',
#       'pluralName': 'Markets',
#       'shortName': 'Market',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/market_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '4b8bf453f964a5207bb432e3',
#     'name': 'Asian Dining',
#     'location': {'address': 'Altstetterstrasse 126',
#      'lat': 47.389569896188185,
#      'lng': 8.486497969079455,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.389569896188185,
#        'lng': 8.486497969079455}],
#      'distance': 4525,
#      'postalCode': '8048',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Altstetterstrasse 126', '8048 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '590862539fca567f1ad45304',
#     'name': 'India Street Food',
#     'location': {'address': 'Kanonengasse 7',
#      'lat': 47.377205,
#      'lng': 8.529052,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.377205,
#        'lng': 8.529052}],
#      'distance': 1099,
#      'postalCode': '8004',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Kanonengasse 7', '8004 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '4ca63d1944a8224bfe5f0140',
#     'name': 'Foodpoint',
#     'location': {'address': 'Köngengasse',
#      'lat': 47.373677,
#      'lng': 8.543674,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.373677,
#        'lng': 8.543674}],
#      'distance': 379,
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Köngengasse', 'Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d1c7941735',
#       'name': 'Snack Place',
#       'pluralName': 'Snack Places',
#       'shortName': 'Snacks',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '4e37f5a3cc3f222897286d3b',
#     'name': "Yooji's Asian Market",
#     'location': {'address': 'Ottenweg 35',
#      'crossStreet': 'im Corner 8 am Kreuzplatz',
#      'lat': 47.364336051752716,
#      'lng': 8.554079532623291,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.364336051752716,
#        'lng': 8.554079532623291}],
#      'distance': 1622,
#      'postalCode': '8008',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Ottenweg 35 (im Corner 8 am Kreuzplatz)',
#       '8008 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d127951735',
#       'name': 'Arts & Crafts Store',
#       'pluralName': 'Arts & Crafts Stores',
#       'shortName': 'Arts & Crafts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/artstore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '5595fd46498e7e817b7f5605',
#     'name': "Vee's Bistro - Thai Food - Take away",
#     'location': {'address': 'Alfred Escher-Strasse 11',
#      'lat': 47.364968319063244,
#      'lng': 8.53271914559729,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.364968319063244,
#        'lng': 8.53271914559729}],
#      'distance': 1579,
#      'postalCode': '8002',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Alfred Escher-Strasse 11', '8002 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '133218568'},
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '576c4f21498e21f5ff463d96',
#     'name': 'Wood food',
#     'location': {'lat': 47.379338,
#      'lng': 8.527168,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.379338,
#        'lng': 8.527168}],
#      'distance': 1266,
#      'cc': 'CH',
#      'country': 'Schweiz'},
#     'categories': [{'id': '4bf58dd8d48988d158941735',
#       'name': 'Swiss Restaurant',
#       'pluralName': 'Swiss Restaurants',
#       'shortName': 'Swiss',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/swiss_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '4c224862fbe5c9b687a29921',
#     'name': 'Roi-Et (ร้อยเอ็ด) (Roi-Et)',
#     'location': {'address': 'Schöneggstrasse 30',
#      'lat': 47.380497246937985,
#      'lng': 8.526089487168502,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.380497246937985,
#        'lng': 8.526089487168502}],
#      'distance': 1376,
#      'postalCode': '8004',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Schöneggstrasse 30', '8004 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '4c91eaaa1adc370491d533d1',
#     'name': "Kepi's Food Station",
#     'location': {'lat': 47.37638335,
#      'lng': 8.52817945,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.37638335,
#        'lng': 8.52817945}],
#      'distance': 1167,
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d115941735',
#       'name': 'Middle Eastern Restaurant',
#       'pluralName': 'Middle Eastern Restaurants',
#       'shortName': 'Middle Eastern',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '4fdb8b53e4b0f86f6abf01d3',
#     'name': "Perinpam's Asian Mart GmbH",
#     'location': {'address': 'Röntgenstrasse 66',
#      'lat': 47.38682878876382,
#      'lng': 8.527701948177592,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.38682878876382,
#        'lng': 8.527701948177592}],
#      'distance': 1618,
#      'postalCode': '8005',
#      'cc': 'CH',
#      'country': 'Schweiz',
#      'formattedAddress': ['Röntgenstrasse 66', '8005']},
#     'categories': [{'id': '4bf58dd8d48988d118951735',
#       'name': 'Grocery Store',
#       'pluralName': 'Grocery Stores',
#       'shortName': 'Grocery Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '55a62cdd498ebfece6815ad9',
#     'name': 'Ayla Real Food',
#     'location': {'address': 'Gasometerstrasse 29',
#      'lat': 47.38734638959699,
#      'lng': 8.527929012234523,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.38734638959699,
#        'lng': 8.527929012234523}],
#      'distance': 1645,
#      'postalCode': '8005',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Gasometerstrasse 29', '8005 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d1d3941735',
#       'name': 'Vegetarian / Vegan Restaurant',
#       'pluralName': 'Vegetarian / Vegan Restaurants',
#       'shortName': 'Vegetarian / Vegan',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '4d42ef777fb05481d21f7079',
#     'name': 'Aggarwal Indian Food',
#     'location': {'address': 'Kernstr. 27',
#      'lat': 47.376312905675576,
#      'lng': 8.525804434563428,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.376312905675576,
#        'lng': 8.525804434563428}],
#      'distance': 1346,
#      'postalCode': '8004',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Kernstr. 27', '8004 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '556368a8498e981961acb23c',
#     'name': 'A1 Albis Asian',
#     'location': {'address': 'Badenerstrasse 298',
#      'lat': 47.376968,
#      'lng': 8.513185,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.376968,
#        'lng': 8.513185}],
#      'distance': 2295,
#      'postalCode': '8004',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Badenerstrasse 298', '8004 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '5af6450da89b5a002f0f73bc',
#     'name': 'Restaurant Spritzwerk',
#     'location': {'address': 'Zollstrasse 80',
#      'crossStreet': 'Amboss Rampe',
#      'lat': 47.381265457694866,
#      'lng': 8.531468510627747,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.381265457694866,
#        'lng': 8.531468510627747}],
#      'distance': 1028,
#      'postalCode': '8005',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Zollstrasse 80 (Amboss Rampe)', '8005 Zürich']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b3d',
#       'name': 'Pop-Up Shop',
#       'pluralName': 'Pop-Up Shops',
#       'shortName': 'Pop-Up Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '4ea328d3b6347b99681cbf35',
#     'name': "Steffi's & Patrick's Vegan food temple",
#     'location': {'address': 'Haslaubstrasse 4',
#      'lat': 47.376211295772016,
#      'lng': 8.52599796827157,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.376211295772016,
#        'lng': 8.52599796827157}],
#      'distance': 1332,
#      'cc': 'CH',
#      'city': 'Schönenberg ZH',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Haslaubstrasse 4', 'Schönenberg ZH']},
#     'categories': [{'id': '4bf58dd8d48988d1d3941735',
#       'name': 'Vegetarian / Vegan Restaurant',
#       'pluralName': 'Vegetarian / Vegan Restaurants',
#       'shortName': 'Vegetarian / Vegan',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '56892102498e4c2af9261d95',
#     'name': 'Sweet Chili Thai Food',
#     'location': {'lat': 47.386702,
#      'lng': 8.502562,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.386702,
#        'lng': 8.502562}],
#      'distance': 3275,
#      'cc': 'CH',
#      'country': 'Schweiz'},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '5c90d310fb8e59002c2a2f2b',
#     'name': 'Mango Food & Drink',
#     'location': {'lat': 47.390561,
#      'lng': 8.539827,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.390561,
#        'lng': 8.539827}],
#      'distance': 1527,
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Zürich']},
#     'categories': [{'id': '4f04af1f2fb6e1c99f3db0bb',
#       'name': 'Turkish Restaurant',
#       'pluralName': 'Turkish Restaurants',
#       'shortName': 'Turkish',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '515abf4fe4b008c4e0dca10d',
#     'name': 'Fine Food Wengihof',
#     'location': {'lat': 47.37474882932138,
#      'lng': 8.523448170208717,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.37474882932138,
#        'lng': 8.523448170208717}],
#      'distance': 1543,
#      'cc': 'CH',
#      'country': 'Schweiz'},
#     'categories': [{'id': '4bf58dd8d48988d1c7941735',
#       'name': 'Snack Place',
#       'pluralName': 'Snack Places',
#       'shortName': 'Snacks',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '4b5df65ff964a520457629e3',
#     'name': 'A1 Albis Asian',
#     'location': {'address': 'Badenerstrasse 298',
#      'lat': 47.3803737946385,
#      'lng': 8.512958071194568,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.3803737946385,
#        'lng': 8.512958071194568}],
#      'distance': 2341,
#      'cc': 'CH',
#      'country': 'Schweiz',
#      'formattedAddress': ['Badenerstrasse 298']},
#     'categories': [],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '544e5a25498ea3736c57aca4',
#     'name': 'marmite food lab',
#     'location': {'address': 'Badenerstrasse 587',
#      'lat': 47.385051343830185,
#      'lng': 8.52694269305286,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.385051343830185,
#        'lng': 8.52694269305286}],
#      'distance': 1539,
#      'postalCode': '8048',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Badenerstrasse 587', '8048 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d171941735',
#       'name': 'Event Space',
#       'pluralName': 'Event Spaces',
#       'shortName': 'Event Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False},
#    {'id': '4f68bc2fe4b0eb0893f34f5d',
#     'name': 'Asian Supermarket',
#     'location': {'lat': 47.41251373039873,
#      'lng': 8.544871991730872,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.41251373039873,
#        'lng': 8.544871991730872}],
#      'distance': 3945,
#      'cc': 'CH',
#      'country': 'Schweiz'},
#     'categories': [{'id': '4bf58dd8d48988d118951735',
#       'name': 'Grocery Store',
#       'pluralName': 'Grocery Stores',
#       'shortName': 'Grocery Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765915',
#     'hasPerk': False}]}}

# %% [markdown]
# ## We will convert this to Pandas dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head(20)
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                           id                                          name  \
# 0   4e5407058877863330aa8874                            Asian Sport Center
# 1   4ec4eefbf790c16e5225be61                     Fo Ke Kio Asian Take Away
# 2   52013213498e9178ab9e16af                 Little Nooch Asian Streetfood
# 3   5193c15b498ec560cd705c47                                Asian-Wellness
# 4   4bf6cf4b4a67c9282a7322cf                                    Asian Moon
# 5   4f5bb376e4b0090c09cda75b                   YEN'S Sushi & Asian Cuisine
# 6   5e0b4830456d3b000815955b                              Viet Street Food
# 7   4b59ca7af964a520369828e3                             India Street-Food
# 8   5bac7c428b98fd0039448a15                                  Food Station
# 9   595a8086c365882ea49c863c                                      Asianart
# 10  4f8d5903e4b0e5ed77fe6a91                         Thai Food Corner GmbH
# 11  5cc1c6a4cabcff002ce22ad4  Coop Supermarkt City Zürich St. Annahof Food
# 12  4d43f0b9bf61a1cdc65c03ac                  Asian Take-Away & Restaurant
# 13  4bf65f0f004ed13a494c42a0                                    Asian Park
# 14  4b5841fff964a520e24f28e3                                      food&lab
# 15  560595f7498eb0f06171956e                            Food  from Farmers
# 16  4e87185182316be403a7f640                       Hong-Kong Food Paradise
# 17  4ccae8789b9346889f9e5141                              Thai Food Corner
# 18  5cc1c8e44a1cc0002c7d8132     Coop Supermarkt City Zürich Bellevue Food
# 19  5357cc16498e0e40db63f54a                           Jelmoli Food Market
#
#                                            categories    referralId  hasPerk  \
# 0   [{'id': '4bf58dd8d48988d1b2941735', 'name': 'C...  v-1620765915    False
# 1   [{'id': '4bf58dd8d48988d142941735', 'name': 'A...  v-1620765915    False
# 2   [{'id': '4bf58dd8d48988d142941735', 'name': 'A...  v-1620765915    False
# 3   [{'id': '4bf58dd8d48988d1ed941735', 'name': 'S...  v-1620765915    False
# 4   [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1620765915    False
# 5   [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...  v-1620765915    False
# 6   [{'id': '4bf58dd8d48988d14a941735', 'name': 'V...  v-1620765915    False
# 7   [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1620765915    False
# 8   [{'id': '4bf58dd8d48988d120951735', 'name': 'F...  v-1620765915    False
# 9   [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1620765915    False
# 10                                                 []  v-1620765915    False
# 11                                                 []  v-1620765915    False
# 12  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...  v-1620765915    False
# 13  [{'id': '4bf58dd8d48988d118951735', 'name': 'G...  v-1620765915    False
# 14  [{'id': '4bf58dd8d48988d128941735', 'name': 'C...  v-1620765915    False
# 15  [{'id': '4bf58dd8d48988d16c941735', 'name': 'B...  v-1620765915    False
# 16  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1620765915    False
# 17  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...  v-1620765915    False
# 18                                                 []  v-1620765915    False
# 19  [{'id': '50be8ee891d4fa8dcc7199a7', 'name': 'M...  v-1620765915    False
#
#     location.lat  location.lng  \
# 0      47.382676      8.547708
# 1      47.372142      8.534841
# 2      47.411235      8.543783
# 3      47.391070      8.538933
# 4      47.363043      8.549531
# 5      47.371369      8.528704
# 6      47.376122      8.536371
# 7      47.383168      8.530197
# 8      47.378204      8.535982
# 9      47.377080      8.523304
# 10     47.379329      8.535520
# 11     47.372902      8.538024
# 12     47.411311      8.545011
# 13     47.386635      8.493780
# 14     47.378327      8.548848
# 15     47.368502      8.545671
# 16     47.374042      8.536562
# 17     47.376984      8.528394
# 18     47.367308      8.546079
# 19     47.374083      8.537229
#
#                               location.labeledLatLngs  location.distance  \
# 0   [{'label': 'display', 'lat': 47.3826760023631,...                694
# 1   [{'label': 'display', 'lat': 47.37214184335466...                861
# 2   [{'label': 'display', 'lat': 47.41123460919642...               3801
# 3   [{'label': 'display', 'lat': 47.39107015696727...               1596
# 4   [{'label': 'display', 'lat': 47.36304278640203...               1625
# 5   [{'label': 'display', 'lat': 47.37136901098179...               1292
# 6   [{'label': 'display', 'lat': 47.376122, 'lng':...                557
# 7   [{'label': 'display', 'lat': 47.383168, 'lng':...               1218
# 8   [{'label': 'display', 'lat': 47.378204, 'lng':...                590
# 9   [{'label': 'display', 'lat': 47.37708, 'lng': ...               1532
# 10  [{'label': 'display', 'lat': 47.37932922752695...                660
# 11  [{'label': 'display', 'lat': 47.37290177, 'lng...                628
# 12  [{'label': 'display', 'lat': 47.41131056035893...               3811
# 13  [{'label': 'display', 'lat': 47.386635, 'lng':...               3905
# 14  [{'label': 'display', 'lat': 47.37832683213607...                416
# 15  [{'label': 'display', 'lat': 47.36850193220842...                967
# 16  [{'label': 'display', 'lat': 47.37404169003569...                631
# 17  [{'label': 'display', 'lat': 47.376984, 'lng':...               1148
# 18  [{'label': 'display', 'lat': 47.367308, 'lng':...               1103
# 19  [{'label': 'display', 'lat': 47.3740827107709,...                587
#
#    location.cc location.city location.state location.country  \
# 0           CH        Zürich         Zürich          Schweiz
# 1           CH        Zürich         Zürich          Schweiz
# 2           CH        Zürich         Zürich          Schweiz
# 3           CH        Zürich         Zürich          Schweiz
# 4           CH        Zürich         Zürich          Schweiz
# 5           CH        Zürich         Zürich          Schweiz
# 6           CH        Zürich         Zürich          Schweiz
# 7           CH        Zürich         Zürich          Schweiz
# 8           CH           NaN            NaN          Schweiz
# 9           CH        Zürich         Zürich          Schweiz
# 10          CH           NaN            NaN          Schweiz
# 11          CH        Zürich         Zürich          Schweiz
# 12          CH        Zürich         Zürich          Schweiz
# 13          CH        Zürich         Zürich          Schweiz
# 14          CH        Zürich         Zürich          Schweiz
# 15          CH        Zürich         Zürich          Schweiz
# 16          CH        Zürich         Zürich          Schweiz
# 17          CH        Zürich         Zürich          Schweiz
# 18          CH        Zürich         Zürich          Schweiz
# 19          CH           NaN            NaN          Schweiz
#
#                             location.formattedAddress        location.address  \
# 0                                            [Zürich]                     NaN
# 1                              [Talacker 50A, Zürich]            Talacker 50A
# 2   [Hofwiesenstr. 369 (Bahnhof Oerlikon), 8050 Zü...       Hofwiesenstr. 369
# 3               [Schaffhauserstrasse 43, 8037 Zürich]  Schaffhauserstrasse 43
# 4   [Seefeldstrasse 40 (at Kreuzstrasse), 8008 Zür...       Seefeldstrasse 40
# 5                     [Hallwylerstr. 43, 8004 Zürich]        Hallwylerstr. 43
# 6                          [Usteristrasse 21, Zürich]        Usteristrasse 21
# 7                      [Langstrasse 213, 8005 Zürich]         Langstrasse 213
# 8                                   [Bahnhofplatz 15]         Bahnhofplatz 15
# 9                  [Schreinerstrasse 64, 8004 Zürich]     Schreinerstrasse 64
# 10                                                NaN                     NaN
# 11                   [Bahnhofstrasse 57, 8001 Zürich]       Bahnhofstrasse 57
# 12                [Hofwiesenstrasse 376, 8050 Zürich]    Hofwiesenstrasse 376
# 13                        [Baslerstrasse 102, Zürich]       Baslerstrasse 102
# 14                             [Rämistr. 101, Zürich]            Rämistr. 101
# 15      [Langstrasse 211 (Josefstrasse), 8005 Zürich]         Langstrasse 211
# 16                       [Seidengasse 1, 8001 Zürich]           Seidengasse 1
# 17                     [Brauerstrasse 3, 8004 Zürich]         Brauerstrasse 3
# 18                   [Theaterstrasse 18, 8024 Zürich]       Theaterstrasse 18
# 19                                                NaN                     NaN
#
#    location.crossStreet location.postalCode location.neighborhood venuePage.id
# 0                   NaN                 NaN                   NaN          NaN
# 1                   NaN                 NaN                   NaN          NaN
# 2      Bahnhof Oerlikon                8050                   NaN          NaN
# 3                   NaN                8037                   NaN          NaN
# 4       at Kreuzstrasse                8008                   NaN          NaN
# 5                   NaN                8004                   NaN          NaN
# 6                   NaN                 NaN                   NaN          NaN
# 7                   NaN                8005                   NaN          NaN
# 8                   NaN                 NaN                   NaN          NaN
# 9                   NaN                8004                   NaN          NaN
# 10                  NaN                 NaN                   NaN          NaN
# 11                  NaN                8001                   NaN          NaN
# 12                  NaN                8050                   NaN          NaN
# 13                  NaN                 NaN                   NaN          NaN
# 14                  NaN                 NaN            Oberstrass          NaN
# 15         Josefstrasse                8005                   NaN          NaN
# 16                  NaN                8001                   NaN          NaN
# 17                  NaN                8004                   NaN          NaN
# 18                  NaN                8024                   NaN          NaN
# 19                  NaN                 NaN                   NaN          NaN

# %% [markdown]
# #### Filtering the data frame

# %%
## keeping only the data frames that is related to venues and locations
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.reindex(columns = filtered_columns)

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else: 
        return(categories_list)[0]['name']
    
# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                             name  \
# 0                             Asian Sport Center
# 1                      Fo Ke Kio Asian Take Away
# 2                  Little Nooch Asian Streetfood
# 3                                 Asian-Wellness
# 4                                     Asian Moon
# 5                    YEN'S Sushi & Asian Cuisine
# 6                               Viet Street Food
# 7                              India Street-Food
# 8                                   Food Station
# 9                                       Asianart
# 10                         Thai Food Corner GmbH
# 11  Coop Supermarkt City Zürich St. Annahof Food
# 12                  Asian Take-Away & Restaurant
# 13                                    Asian Park
# 14                                      food&lab
# 15                            Food  from Farmers
# 16                       Hong-Kong Food Paradise
# 17                              Thai Food Corner
# 18     Coop Supermarkt City Zürich Bellevue Food
# 19                           Jelmoli Food Market
# 20                                  Asian Dining
# 21                             India Street Food
# 22                                     Foodpoint
# 23                          Yooji's Asian Market
# 24          Vee's Bistro - Thai Food - Take away
# 25                                     Wood food
# 26                    Roi-Et (ร้อยเอ็ด) (Roi-Et)
# 27                           Kepi's Food Station
# 28                    Perinpam's Asian Mart GmbH
# 29                                Ayla Real Food
# 30                          Aggarwal Indian Food
# 31                                A1 Albis Asian
# 32                         Restaurant Spritzwerk
# 33        Steffi's & Patrick's Vegan food temple
# 34                         Sweet Chili Thai Food
# 35                            Mango Food & Drink
# 36                            Fine Food Wengihof
# 37                                A1 Albis Asian
# 38                              marmite food lab
# 39                             Asian Supermarket
#
#                        categories        lat       lng  \
# 0                     College Gym  47.382676  8.547708
# 1                Asian Restaurant  47.372142  8.534841
# 2                Asian Restaurant  47.411235  8.543783
# 3                             Spa  47.391070  8.538933
# 4              Chinese Restaurant  47.363043  8.549531
# 5                Sushi Restaurant  47.371369  8.528704
# 6           Vietnamese Restaurant  47.376122  8.536371
# 7               Indian Restaurant  47.383168  8.530197
# 8                      Food Court  47.378204  8.535982
# 9              Chinese Restaurant  47.377080  8.523304
# 10                           None  47.379329  8.535520
# 11                           None  47.372902  8.538024
# 12               Asian Restaurant  47.411311  8.545011
# 13                  Grocery Store  47.386635  8.493780
# 14                      Cafeteria  47.378327  8.548848
# 15                   Burger Joint  47.368502  8.545671
# 16             Chinese Restaurant  47.374042  8.536562
# 17                Thai Restaurant  47.376984  8.528394
# 18                           None  47.367308  8.546079
# 19                         Market  47.374083  8.537229
# 20               Asian Restaurant  47.389570  8.486498
# 21              Indian Restaurant  47.377205  8.529052
# 22                    Snack Place  47.373677  8.543674
# 23            Arts & Crafts Store  47.364336  8.554080
# 24                Thai Restaurant  47.364968  8.532719
# 25               Swiss Restaurant  47.379338  8.527168
# 26                Thai Restaurant  47.380497  8.526089
# 27      Middle Eastern Restaurant  47.376383  8.528179
# 28                  Grocery Store  47.386829  8.527702
# 29  Vegetarian / Vegan Restaurant  47.387346  8.527929
# 30               Asian Restaurant  47.376313  8.525804
# 31               Asian Restaurant  47.376968  8.513185
# 32                    Pop-Up Shop  47.381265  8.531469
# 33  Vegetarian / Vegan Restaurant  47.376211  8.525998
# 34                Thai Restaurant  47.386702  8.502562
# 35             Turkish Restaurant  47.390561  8.539827
# 36                    Snack Place  47.374749  8.523448
# 37                           None  47.380374  8.512958
# 38                    Event Space  47.385051  8.526943
# 39                  Grocery Store  47.412514  8.544872
#
#                                        labeledLatLngs  distance  cc  \
# 0   [{'label': 'display', 'lat': 47.3826760023631,...       694  CH
# 1   [{'label': 'display', 'lat': 47.37214184335466...       861  CH
# 2   [{'label': 'display', 'lat': 47.41123460919642...      3801  CH
# 3   [{'label': 'display', 'lat': 47.39107015696727...      1596  CH
# 4   [{'label': 'display', 'lat': 47.36304278640203...      1625  CH
# 5   [{'label': 'display', 'lat': 47.37136901098179...      1292  CH
# 6   [{'label': 'display', 'lat': 47.376122, 'lng':...       557  CH
# 7   [{'label': 'display', 'lat': 47.383168, 'lng':...      1218  CH
# 8   [{'label': 'display', 'lat': 47.378204, 'lng':...       590  CH
# 9   [{'label': 'display', 'lat': 47.37708, 'lng': ...      1532  CH
# 10  [{'label': 'display', 'lat': 47.37932922752695...       660  CH
# 11  [{'label': 'display', 'lat': 47.37290177, 'lng...       628  CH
# 12  [{'label': 'display', 'lat': 47.41131056035893...      3811  CH
# 13  [{'label': 'display', 'lat': 47.386635, 'lng':...      3905  CH
# 14  [{'label': 'display', 'lat': 47.37832683213607...       416  CH
# 15  [{'label': 'display', 'lat': 47.36850193220842...       967  CH
# 16  [{'label': 'display', 'lat': 47.37404169003569...       631  CH
# 17  [{'label': 'display', 'lat': 47.376984, 'lng':...      1148  CH
# 18  [{'label': 'display', 'lat': 47.367308, 'lng':...      1103  CH
# 19  [{'label': 'display', 'lat': 47.3740827107709,...       587  CH
# 20  [{'label': 'display', 'lat': 47.38956989618818...      4525  CH
# 21  [{'label': 'display', 'lat': 47.377205, 'lng':...      1099  CH
# 22  [{'label': 'display', 'lat': 47.373677, 'lng':...       379  CH
# 23  [{'label': 'display', 'lat': 47.36433605175271...      1622  CH
# 24  [{'label': 'display', 'lat': 47.36496831906324...      1579  CH
# 25  [{'label': 'display', 'lat': 47.379338, 'lng':...      1266  CH
# 26  [{'label': 'display', 'lat': 47.38049724693798...      1376  CH
# 27  [{'label': 'display', 'lat': 47.37638335, 'lng...      1167  CH
# 28  [{'label': 'display', 'lat': 47.38682878876382...      1618  CH
# 29  [{'label': 'display', 'lat': 47.38734638959699...      1645  CH
# 30  [{'label': 'display', 'lat': 47.37631290567557...      1346  CH
# 31  [{'label': 'display', 'lat': 47.376968, 'lng':...      2295  CH
# 32  [{'label': 'display', 'lat': 47.38126545769486...      1028  CH
# 33  [{'label': 'display', 'lat': 47.37621129577201...      1332  CH
# 34  [{'label': 'display', 'lat': 47.386702, 'lng':...      3275  CH
# 35  [{'label': 'display', 'lat': 47.390561, 'lng':...      1527  CH
# 36  [{'label': 'display', 'lat': 47.37474882932138...      1543  CH
# 37  [{'label': 'display', 'lat': 47.3803737946385,...      2341  CH
# 38  [{'label': 'display', 'lat': 47.38505134383018...      1539  CH
# 39  [{'label': 'display', 'lat': 47.41251373039873...      3945  CH
#
#               city   state  country  \
# 0           Zürich  Zürich  Schweiz
# 1           Zürich  Zürich  Schweiz
# 2           Zürich  Zürich  Schweiz
# 3           Zürich  Zürich  Schweiz
# 4           Zürich  Zürich  Schweiz
# 5           Zürich  Zürich  Schweiz
# 6           Zürich  Zürich  Schweiz
# 7           Zürich  Zürich  Schweiz
# 8              NaN     NaN  Schweiz
# 9           Zürich  Zürich  Schweiz
# 10             NaN     NaN  Schweiz
# 11          Zürich  Zürich  Schweiz
# 12          Zürich  Zürich  Schweiz
# 13          Zürich  Zürich  Schweiz
# 14          Zürich  Zürich  Schweiz
# 15          Zürich  Zürich  Schweiz
# 16          Zürich  Zürich  Schweiz
# 17          Zürich  Zürich  Schweiz
# 18          Zürich  Zürich  Schweiz
# 19             NaN     NaN  Schweiz
# 20          Zürich  Zürich  Schweiz
# 21          Zürich  Zürich  Schweiz
# 22          Zürich  Zürich  Schweiz
# 23          Zürich  Zürich  Schweiz
# 24          Zürich  Zürich  Schweiz
# 25             NaN     NaN  Schweiz
# 26          Zürich  Zürich  Schweiz
# 27          Zürich  Zürich  Schweiz
# 28             NaN     NaN  Schweiz
# 29          Zürich  Zürich  Schweiz
# 30          Zürich  Zürich  Schweiz
# 31          Zürich  Zürich  Schweiz
# 32          Zürich  Zürich  Schweiz
# 33  Schönenberg ZH  Zürich  Schweiz
# 34             NaN     NaN  Schweiz
# 35          Zürich  Zürich  Schweiz
# 36             NaN     NaN  Schweiz
# 37             NaN     NaN  Schweiz
# 38          Zürich  Zürich  Schweiz
# 39             NaN     NaN  Schweiz
#
#                                      formattedAddress  \
# 0                                            [Zürich]
# 1                              [Talacker 50A, Zürich]
# 2   [Hofwiesenstr. 369 (Bahnhof Oerlikon), 8050 Zü...
# 3               [Schaffhauserstrasse 43, 8037 Zürich]
# 4   [Seefeldstrasse 40 (at Kreuzstrasse), 8008 Zür...
# 5                     [Hallwylerstr. 43, 8004 Zürich]
# 6                          [Usteristrasse 21, Zürich]
# 7                      [Langstrasse 213, 8005 Zürich]
# 8                                   [Bahnhofplatz 15]
# 9                  [Schreinerstrasse 64, 8004 Zürich]
# 10                                                NaN
# 11                   [Bahnhofstrasse 57, 8001 Zürich]
# 12                [Hofwiesenstrasse 376, 8050 Zürich]
# 13                        [Baslerstrasse 102, Zürich]
# 14                             [Rämistr. 101, Zürich]
# 15      [Langstrasse 211 (Josefstrasse), 8005 Zürich]
# 16                       [Seidengasse 1, 8001 Zürich]
# 17                     [Brauerstrasse 3, 8004 Zürich]
# 18                   [Theaterstrasse 18, 8024 Zürich]
# 19                                                NaN
# 20               [Altstetterstrasse 126, 8048 Zürich]
# 21                      [Kanonengasse 7, 8004 Zürich]
# 22                              [Köngengasse, Zürich]
# 23  [Ottenweg 35 (im Corner 8 am Kreuzplatz), 8008...
# 24            [Alfred Escher-Strasse 11, 8002 Zürich]
# 25                                                NaN
# 26                  [Schöneggstrasse 30, 8004 Zürich]
# 27                                           [Zürich]
# 28                          [Röntgenstrasse 66, 8005]
# 29                 [Gasometerstrasse 29, 8005 Zürich]
# 30                         [Kernstr. 27, 8004 Zürich]
# 31                  [Badenerstrasse 298, 8004 Zürich]
# 32       [Zollstrasse 80 (Amboss Rampe), 8005 Zürich]
# 33                 [Haslaubstrasse 4, Schönenberg ZH]
# 34                                                NaN
# 35                                           [Zürich]
# 36                                                NaN
# 37                               [Badenerstrasse 298]
# 38                  [Badenerstrasse 587, 8048 Zürich]
# 39                                                NaN
#
#                      address                crossStreet postalCode  \
# 0                        NaN                        NaN        NaN
# 1               Talacker 50A                        NaN        NaN
# 2          Hofwiesenstr. 369           Bahnhof Oerlikon       8050
# 3     Schaffhauserstrasse 43                        NaN       8037
# 4          Seefeldstrasse 40            at Kreuzstrasse       8008
# 5           Hallwylerstr. 43                        NaN       8004
# 6           Usteristrasse 21                        NaN        NaN
# 7            Langstrasse 213                        NaN       8005
# 8            Bahnhofplatz 15                        NaN        NaN
# 9        Schreinerstrasse 64                        NaN       8004
# 10                       NaN                        NaN        NaN
# 11         Bahnhofstrasse 57                        NaN       8001
# 12      Hofwiesenstrasse 376                        NaN       8050
# 13         Baslerstrasse 102                        NaN        NaN
# 14              Rämistr. 101                        NaN        NaN
# 15           Langstrasse 211               Josefstrasse       8005
# 16             Seidengasse 1                        NaN       8001
# 17           Brauerstrasse 3                        NaN       8004
# 18         Theaterstrasse 18                        NaN       8024
# 19                       NaN                        NaN        NaN
# 20     Altstetterstrasse 126                        NaN       8048
# 21            Kanonengasse 7                        NaN       8004
# 22               Köngengasse                        NaN        NaN
# 23               Ottenweg 35  im Corner 8 am Kreuzplatz       8008
# 24  Alfred Escher-Strasse 11                        NaN       8002
# 25                       NaN                        NaN        NaN
# 26        Schöneggstrasse 30                        NaN       8004
# 27                       NaN                        NaN        NaN
# 28         Röntgenstrasse 66                        NaN       8005
# 29       Gasometerstrasse 29                        NaN       8005
# 30               Kernstr. 27                        NaN       8004
# 31        Badenerstrasse 298                        NaN       8004
# 32            Zollstrasse 80               Amboss Rampe       8005
# 33          Haslaubstrasse 4                        NaN        NaN
# 34                       NaN                        NaN        NaN
# 35                       NaN                        NaN        NaN
# 36                       NaN                        NaN        NaN
# 37        Badenerstrasse 298                        NaN        NaN
# 38        Badenerstrasse 587                        NaN       8048
# 39                       NaN                        NaN        NaN
#
#    neighborhood                        id
# 0           NaN  4e5407058877863330aa8874
# 1           NaN  4ec4eefbf790c16e5225be61
# 2           NaN  52013213498e9178ab9e16af
# 3           NaN  5193c15b498ec560cd705c47
# 4           NaN  4bf6cf4b4a67c9282a7322cf
# 5           NaN  4f5bb376e4b0090c09cda75b
# 6           NaN  5e0b4830456d3b000815955b
# 7           NaN  4b59ca7af964a520369828e3
# 8           NaN  5bac7c428b98fd0039448a15
# 9           NaN  595a8086c365882ea49c863c
# 10          NaN  4f8d5903e4b0e5ed77fe6a91
# 11          NaN  5cc1c6a4cabcff002ce22ad4
# 12          NaN  4d43f0b9bf61a1cdc65c03ac
# 13          NaN  4bf65f0f004ed13a494c42a0
# 14   Oberstrass  4b5841fff964a520e24f28e3
# 15          NaN  560595f7498eb0f06171956e
# 16          NaN  4e87185182316be403a7f640
# 17          NaN  4ccae8789b9346889f9e5141
# 18          NaN  5cc1c8e44a1cc0002c7d8132
# 19          NaN  5357cc16498e0e40db63f54a
# 20          NaN  4b8bf453f964a5207bb432e3
# 21          NaN  590862539fca567f1ad45304
# 22          NaN  4ca63d1944a8224bfe5f0140
# 23          NaN  4e37f5a3cc3f222897286d3b
# 24          NaN  5595fd46498e7e817b7f5605
# 25          NaN  576c4f21498e21f5ff463d96
# 26          NaN  4c224862fbe5c9b687a29921
# 27          NaN  4c91eaaa1adc370491d533d1
# 28          NaN  4fdb8b53e4b0f86f6abf01d3
# 29          NaN  55a62cdd498ebfece6815ad9
# 30          NaN  4d42ef777fb05481d21f7079
# 31          NaN  556368a8498e981961acb23c
# 32          NaN  5af6450da89b5a002f0f73bc
# 33          NaN  4ea328d3b6347b99681cbf35
# 34          NaN  56892102498e4c2af9261d95
# 35          NaN  5c90d310fb8e59002c2a2f2b
# 36          NaN  515abf4fe4b008c4e0dca10d
# 37          NaN  4b5df65ff964a520457629e3
# 38          NaN  544e5a25498ea3736c57aca4
# 39          NaN  4f68bc2fe4b0eb0893f34f5d

# %% [markdown]
# ## Lets generate the Map with the help of folium

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start =15)

#To locate the central plaza, using red mark on the map
folium.CircleMarker(
    [latitude, longitude],
    radius=20,
    color = 'red',
    popup='Central Plaza',
    fill = 'True',
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# To locate the Indian resturant, using green mark on the map
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=10,
        color = 'green',
        popup = label,
        fill = 'True'
).add_to(venues_map)

venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_e2a8d76e97b14810bd973dbdac72c95b%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e2a8d76e97b14810bd973dbdac72c95b%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_e2a8d76e97b14810bd973dbdac72c95b%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_e2a8d76e97b14810bd973dbdac72c95b%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B47.3770836%2C8.543634%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2015%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ## Lets go to our near hotels of Zurich

# %%
#Now the above Map has all the resturants in Zurich, Now we will Locate the nearby hotels and will visulaize

search_query = 'Hotels'
radius = 5000
print(search_query + ' .... OK!')
# Out:
# Hotels .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=M0XKWEK2RJZSE5XJIH0MPUBZPWZ2UGFUEGK5YCO1HGVGNGSU&client_secret=YMYYBKNJXFSPZ5XX1BMHJIZC0IDKVDYHFLODBWVHHCJALL5F&ll=47.3770836,8.543634&oauth_token=DNGKZPAWP3VZZTOT0LXWDZGEEQXRQJZIJ0TU0NKOUBMOVLWD&v=20180604&query=Hotels&radius=5000&limit=40'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '609aecf7989a3538337f160e'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'venues': [{'id': '4f192576e4b00583e7aecae5',
#     'name': 'Chreis 4 Hotels / Gastenhaus',
#     'location': {'lat': 47.377868,
#      'lng': 8.528536,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.377868,
#        'lng': 8.528536}],
#      'distance': 1141,
#      'cc': 'CH',
#      'country': 'Schweiz'},
#     'categories': [],
#     'referralId': 'v-1620765943',
#     'hasPerk': False},
#    {'id': '4f9b25dce4b020e60ecae7e7',
#     'name': 'Chreis Hotels 4, Lodges',
#     'location': {'address': 'Anwandstrasse 10',
#      'lat': 47.37620385434355,
#      'lng': 8.524694040843906,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.37620385434355,
#        'lng': 8.524694040843906}],
#      'distance': 1431,
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Anwandstrasse 10', 'Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765943',
#     'hasPerk': False},
#    {'id': '4e58f05db0fbdca309f5e43f',
#     'name': 'Hotel Scheuble',
#     'location': {'lat': 47.37444716313871,
#      'lng': 8.544850575490287,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.37444716313871,
#        'lng': 8.544850575490287}],
#      'distance': 307,
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765943',
#     'hasPerk': False},
#    {'id': '4b39fc23f964a520046025e3',
#     'name': 'Hotel Storchen',
#     'location': {'address': 'Am Weinplatz 2',
#      'lat': 47.37126567053149,
#      'lng': 8.542178260289402,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.37126567053149,
#        'lng': 8.542178260289402}],
#      'distance': 656,
#      'postalCode': '8001',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Am Weinplatz 2', '8001 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765943',
#     'hasPerk': False},
#    {'id': '4b058887f964a520b8cb22e3',
#     'name': 'Hotel Schweizerhof Zürich',
#     'location': {'address': 'Bahnhofplatz 7',
#      'lat': 47.37704590573849,
#      'lng': 8.539562147437913,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.37704590573849,
#        'lng': 8.539562147437913}],
#      'distance': 306,
#      'postalCode': '8001',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Bahnhofplatz 7', '8001 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765943',
#     'hasPerk': False},
#    {'id': '4b058887f964a520bccb22e3',
#     'name': 'Hotel St. Gotthard',
#     'location': {'address': 'Bahnhofstrasse 87',
#      'lat': 47.37633173599005,
#      'lng': 8.538936630791838,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.37633173599005,
#        'lng': 8.538936630791838}],
#      'distance': 363,
#      'postalCode': '8021',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Bahnhofstrasse 87', '8021 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765943',
#     'hasPerk': False},
#    {'id': '5d88688c229a2400089f4135',
#     'name': 'Hotel Schweizerhof Fitness Center',
#     'location': {'lat': 47.376946,
#      'lng': 8.539385,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.376946,
#        'lng': 8.539385}],
#      'distance': 320,
#      'cc': 'CH',
#      'country': 'Schweiz'},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765943',
#     'hasPerk': False},
#    {'id': '4b058886f964a5207ccb22e3',
#     'name': 'Zurich Marriott Hotel',
#     'location': {'address': 'Neumuehlequai 42',
#      'lat': 47.382572,
#      'lng': 8.540505,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.382572,
#        'lng': 8.540505}],
#      'distance': 654,
#      'postalCode': '8006',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Neumuehlequai 42', '8006 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '34923067'},
#     'referralId': 'v-1620765943',
#     'hasPerk': False},
#    {'id': '4b7edea6f964a5209d0530e3',
#     'name': 'Hotel Seehof Bar',
#     'location': {'lat': 47.364326365611646,
#      'lng': 8.54787282001232,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.364326365611646,
#        'lng': 8.54787282001232}],
#      'distance': 1455,
#      'cc': 'CH',
#      'country': 'Schweiz'},
#     'categories': [{'id': '4bf58dd8d48988d1c0941735',
#       'name': 'Mediterranean Restaurant',
#       'pluralName': 'Mediterranean Restaurants',
#       'shortName': 'Mediterranean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765943',
#     'hasPerk': False},
#    {'id': '504275c4e4b0b6cb2f567836',
#     'name': 'Hotel Seehof',
#     'location': {'address': 'Seehofstrasse 11',
#      'lat': 47.364307609791425,
#      'lng': 8.547860612161577,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.364307609791425,
#        'lng': 8.547860612161577}],
#      'distance': 1457,
#      'postalCode': '8008',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Seehofstrasse 11', '8008 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765943',
#     'hasPerk': False},
#    {'id': '4b058887f964a5208fcb22e3',
#     'name': 'Hotel Seegarten',
#     'location': {'address': 'Seegartenstrasse 14',
#      'crossStreet': 'Dufourstrasse',
#      'lat': 47.36151505590732,
#      'lng': 8.549416682396288,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.36151505590732,
#        'lng': 8.549416682396288}],
#      'distance': 1787,
#      'postalCode': '8008',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Seegartenstrasse 14 (Dufourstrasse)',
#       '8008 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765943',
#     'hasPerk': False},
#    {'id': '5b802d6a89ad460024ba2de1',
#     'name': 'Atlantis by Giardino, Zurich, a Member of Design Hotels',
#     'location': {'address': 'Doeltschiweg 234',
#      'lat': 47.363031608100535,
#      'lng': 8.495707958936691,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.363031608100535,
#        'lng': 8.495707958936691}],
#      'distance': 3937,
#      'postalCode': '8055',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Doeltschiweg 234', '8055 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765943',
#     'hasPerk': False},
#    {'id': '4b058887f964a520a4cb22e3',
#     'name': 'Sorell Hotel Seidenhof',
#     'location': {'address': 'Sihlstrasse 9',
#      'lat': 47.37376283395256,
#      'lng': 8.537319560527326,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.37376283395256,
#        'lng': 8.537319560527326}],
#      'distance': 602,
#      'postalCode': '8001',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Sihlstrasse 9', '8001 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765943',
#     'hasPerk': False},
#    {'id': '5640d43fcd10abb6a9ec4c75',
#     'name': 'Hotel Senator Fitness',
#     'location': {'lat': 47.38957214355469,
#      'lng': 8.522224426269531,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.38957214355469,
#        'lng': 8.522224426269531}],
#      'distance': 2129,
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Zürich']},
#     'categories': [{'id': '4f4528bc4b90abdf24c9de85',
#       'name': 'Athletics & Sports',
#       'pluralName': 'Athletics & Sports',
#       'shortName': 'Athletics & Sports',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765943',
#     'hasPerk': False},
#    {'id': '4b058886f964a5207ecb22e3',
#     'name': 'Sheraton Zurich Neues Schloss Hotel',
#     'location': {'address': 'Stockerstrasse 17',
#      'crossStreet': 'Neues Schloss',
#      'lat': 47.36547142088256,
#      'lng': 8.53593991136222,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.36547142088256,
#        'lng': 8.53593991136222}],
#      'distance': 1416,
#      'postalCode': '8002',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Stockerstrasse 17 (Neues Schloss)', '8002 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765943',
#     'hasPerk': False},
#    {'id': '4b6f0737f964a520ebd72ce3',
#     'name': 'Hotel Sternen Oerlikon Brasserie Ö',
#     'location': {'address': 'Schaffhauserstr. 335',
#      'lat': 47.4085323803937,
#      'lng': 8.546499764587786,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.4085323803937,
#        'lng': 8.546499764587786}],
#      'distance': 3507,
#      'postalCode': '8050',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Schaffhauserstr. 335', '8050 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '45657280'},
#     'referralId': 'v-1620765943',
#     'hasPerk': False},
#    {'id': '4b9ec7a7f964a520440137e3',
#     'name': 'Swissôtel Zurich',
#     'location': {'address': 'Schulstrasse 44',
#      'crossStreet': 'Hofwiesenstr.',
#      'lat': 47.41076450757599,
#      'lng': 8.543725270552267,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.41076450757599,
#        'lng': 8.543725270552267}],
#      'distance': 3749,
#      'postalCode': '8050',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Schulstrasse 44 (Hofwiesenstr.)', '8050 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765943',
#     'hasPerk': False},
#    {'id': '4b058887f964a520b5cb22e3',
#     'name': 'Alden Hotel Splügenschloss',
#     'location': {'address': 'Splügenstr. 2',
#      'lat': 47.36462286520168,
#      'lng': 8.534343826219231,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.36462286520168,
#        'lng': 8.534343826219231}],
#      'distance': 1553,
#      'postalCode': '8002',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Splügenstr. 2', '8002 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765943',
#     'hasPerk': False},
#    {'id': '4b058887f964a520a5cb22e3',
#     'name': 'Sorell Hotel Seefeld',
#     'location': {'address': 'Seefeldstrasse 63',
#      'lat': 47.36162815618858,
#      'lng': 8.551242965487926,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.36162815618858,
#        'lng': 8.551242965487926}],
#      'distance': 1813,
#      'postalCode': '8008',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Seefeldstrasse 63', '8008 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765943',
#     'hasPerk': False},
#    {'id': '524ee892498e44925cd2a2de',
#     'name': 'DIE BAR im Hotel Seefeld',
#     'location': {'address': 'Seefeldstrasse 63',
#      'lat': 47.3615652068353,
#      'lng': 8.55132814237826,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.3615652068353,
#        'lng': 8.55132814237826}],
#      'distance': 1822,
#      'postalCode': '8008',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Seefeldstrasse 63', '8008 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d1d5941735',
#       'name': 'Hotel Bar',
#       'pluralName': 'Hotel Bars',
#       'shortName': 'Hotel Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765943',
#     'hasPerk': False},
#    {'id': '4b058887f964a520b4cb22e3',
#     'name': 'Mercure Hotel Stoller',
#     'location': {'address': 'Badenerstrasse 357',
#      'lat': 47.37851593369581,
#      'lng': 8.50920478157991,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.37851593369581,
#        'lng': 8.50920478157991}],
#      'distance': 2600,
#      'postalCode': '8003',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Badenerstrasse 357', '8003 Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765943',
#     'hasPerk': False},
#    {'id': '4bc87c64dc55eee1807ee8ac',
#     'name': 'Ibis Hotel',
#     'location': {'address': 'Heidi Abel Weg 5',
#      'lat': 47.415999163020956,
#      'lng': 8.558957627693212,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.415999163020956,
#        'lng': 8.558957627693212}],
#      'distance': 4483,
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Heidi Abel Weg 5', 'Zürich']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765943',
#     'hasPerk': False},
#    {'id': '59347dfe5ba04607d203f80b',
#     'name': '25hour Hotel Spa & Sauna',
#     'location': {'address': 'Pfingstweidstr. 102',
#      'lat': 47.390923,
#      'lng': 8.509913,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.390923,
#        'lng': 8.509913}],
#      'distance': 2972,
#      'postalCode': '8005',
#      'cc': 'CH',
#      'city': 'Zürich',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Pfingstweidstr. 102', '8005 Zürich']},
#     'categories': [{'id': '58daa1558bbb0b01f18ec1ae',
#       'name': 'Sauna / Steam Room',
#       'pluralName': 'Saunas / Steam Rooms',
#       'shortName': 'Sauna / Steam Room',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765943',
#     'hasPerk': False},
#    {'id': '4b058887f964a52087cb22e3',
#     'name': 'Sorell Hotel Sonnental',
#     'location': {'address': 'Zurichstrasse 94/96',
#      'lat': 47.39567463266965,
#      'lng': 8.604199876666366,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.39567463266965,
#        'lng': 8.604199876666366}],
#      'distance': 5011,
#      'postalCode': '8600',
#      'cc': 'CH',
#      'city': 'Dübendorf',
#      'state': 'Zürich',
#      'country': 'Schweiz',
#      'formattedAddress': ['Zurichstrasse 94/96', '8600 Dübendorf']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620765943',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                          name  \
# 0  4f192576e4b00583e7aecae5  Chreis 4 Hotels / Gastenhaus
# 1  4f9b25dce4b020e60ecae7e7       Chreis Hotels 4, Lodges
# 2  4e58f05db0fbdca309f5e43f                Hotel Scheuble
# 3  4b39fc23f964a520046025e3                Hotel Storchen
# 4  4b058887f964a520b8cb22e3     Hotel Schweizerhof Zürich
#
#                                           categories    referralId  hasPerk  \
# 0                                                 []  v-1620765943    False
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1620765943    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1620765943    False
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1620765943    False
# 4  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1620765943    False
#
#    location.lat  location.lng  \
# 0     47.377868      8.528536
# 1     47.376204      8.524694
# 2     47.374447      8.544851
# 3     47.371266      8.542178
# 4     47.377046      8.539562
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 47.377868, 'lng':...               1141
# 1  [{'label': 'display', 'lat': 47.37620385434355...               1431
# 2  [{'label': 'display', 'lat': 47.37444716313871...                307
# 3  [{'label': 'display', 'lat': 47.37126567053149...                656
# 4  [{'label': 'display', 'lat': 47.37704590573849...                306
#
#   location.cc location.country  location.address location.city location.state  \
# 0          CH          Schweiz               NaN           NaN            NaN
# 1          CH          Schweiz  Anwandstrasse 10        Zürich         Zürich
# 2          CH          Schweiz               NaN        Zürich         Zürich
# 3          CH          Schweiz    Am Weinplatz 2        Zürich         Zürich
# 4          CH          Schweiz    Bahnhofplatz 7        Zürich         Zürich
#
#        location.formattedAddress location.postalCode venuePage.id  \
# 0                            NaN                 NaN          NaN
# 1     [Anwandstrasse 10, Zürich]                 NaN          NaN
# 2                       [Zürich]                 NaN          NaN
# 3  [Am Weinplatz 2, 8001 Zürich]                8001          NaN
# 4  [Bahnhofplatz 7, 8001 Zürich]                8001          NaN
#
#   location.crossStreet
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
## keeping only the data frames that is related to venues and locations
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
df_fil_hotel = dataframe.reindex(columns = filtered_columns)

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else: 
        return(categories_list)[0]['name']
    
# filter the category for each row
df_fil_hotel['categories'] = df_fil_hotel.apply(get_category_type, axis=1)

# clean column names by keeping only last term
df_fil_hotel.columns = [column.split('.')[-1] for column in df_fil_hotel.columns]

df_fil_hotel.head()
# Out:
#                            name categories        lat       lng  \
# 0  Chreis 4 Hotels / Gastenhaus       None  47.377868  8.528536
# 1       Chreis Hotels 4, Lodges      Hotel  47.376204  8.524694
# 2                Hotel Scheuble      Hotel  47.374447  8.544851
# 3                Hotel Storchen      Hotel  47.371266  8.542178
# 4     Hotel Schweizerhof Zürich      Hotel  47.377046  8.539562
#
#                                       labeledLatLngs  distance  cc  country  \
# 0  [{'label': 'display', 'lat': 47.377868, 'lng':...      1141  CH  Schweiz
# 1  [{'label': 'display', 'lat': 47.37620385434355...      1431  CH  Schweiz
# 2  [{'label': 'display', 'lat': 47.37444716313871...       307  CH  Schweiz
# 3  [{'label': 'display', 'lat': 47.37126567053149...       656  CH  Schweiz
# 4  [{'label': 'display', 'lat': 47.37704590573849...       306  CH  Schweiz
#
#             address    city   state               formattedAddress postalCode  \
# 0               NaN     NaN     NaN                            NaN        NaN
# 1  Anwandstrasse 10  Zürich  Zürich     [Anwandstrasse 10, Zürich]        NaN
# 2               NaN  Zürich  Zürich                       [Zürich]        NaN
# 3    Am Weinplatz 2  Zürich  Zürich  [Am Weinplatz 2, 8001 Zürich]       8001
# 4    Bahnhofplatz 7  Zürich  Zürich  [Bahnhofplatz 7, 8001 Zürich]       8001
#
#   crossStreet                        id
# 0         NaN  4f192576e4b00583e7aecae5
# 1         NaN  4f9b25dce4b020e60ecae7e7
# 2         NaN  4e58f05db0fbdca309f5e43f
# 3         NaN  4b39fc23f964a520046025e3
# 4         NaN  4b058887f964a520b8cb22e3

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start =15)

#To locate the central plaza, using red mark on the map
folium.CircleMarker(
    [latitude, longitude],
    radius=20,
    color = 'red',
    popup='Central Plaza',
    fill = 'True',
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# To locate the Hotels, using green mark on the map
for lat, lng, label in zip(df_fil_hotel.lat, df_fil_hotel.lng, df_fil_hotel.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=10,
        color = 'green',
        popup = label,
        fill = 'True'
).add_to(venues_map)

venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_4fa0b5df211142dd8dc8b2b6d4fddef4%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4fa0b5df211142dd8dc8b2b6d4fddef4%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_4fa0b5df211142dd8dc8b2b6d4fddef4%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_4fa0b5df211142dd8dc8b2b6d4fddef4%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B47.3770836%2C8.543634%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2015%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# #### Now we will create global map hotels vs Asian Resturants

# %%
Global_Map = folium.Map(location=[latitude, longitude], zoom_start =15)

#To locate the central plaza, using red mark on the map
folium.CircleMarker(
    [latitude, longitude],
    radius=20,
    color = 'red',
    popup='Central Plaza',
    fill = 'True',
    fill_color = 'Yellow',
    fill_opacity = 0.6
).add_to(Global_Map)

# To locate the Hotels, using green mark on the map
for lat, lng, label in zip(df_fil_hotel.lat, df_fil_hotel.lng, df_fil_hotel.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=10,
        color = 'green',
        popup = label,
        fill = 'True'
).add_to(Global_Map)
# To locate the Asian Resturants, using Red mark on the map
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=10,
        color = 'red',
        popup = label,
        fill = 'True'
).add_to(Global_Map)


Global_Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_ba3c7f011fbc488aad11fa15919b7557%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ba3c7f011fbc488aad11fa15919b7557%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_ba3c7f011fbc488aad11fa15919b7557%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_ba3c7f011fbc488aad11fa15919b7557%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B47.3770836%2C8.543634%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2015%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ###### We will now focus on spotting worker area more than competitors, we will try do determine where are clusters more of the worker.
# In order to do that, we will use the k mean clustering method.

# %%
# Importing librariers for Clustering
import random # library for random number generation
import numpy as np # library for vectorized computation
import pandas as pd # library to process data as dataframes

import matplotlib.pyplot as plt # plotting library
# backend for rendering plots within the browser

# %matplotlib inline 
from sklearn.cluster import KMeans 
from sklearn.datasets.samples_generator import make_blobs

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ### Creating a dataframe to perform clustering

# %%
# define URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# send GET request and get trending venues
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '609aed0babb8ae2261aa0623'},
#  'response': {'venues': []}}

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %%
trending_venues_df
# Out:
# 'No trending venues are available at the moment!'

# %%
import numpy as np
import pandas as pd
import json

import requests
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium
# !pip install html5lib
# !pip install lxml
# !pip install BeautifulSoup4

print('librariers are imported')
# Out:
# Requirement already satisfied: html5lib in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.9999999)
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from html5lib) (1.15.0)
# Requirement already satisfied: lxml in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (4.6.3)
# Requirement already satisfied: BeautifulSoup4 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (4.9.3)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from BeautifulSoup4) (2.2.1)
# librariers are imported

# %%
from pandas.io.html import read_html
url ='https://www.geonames.org/postalcode-search.html?q=&country=CH&adminCode1=ZH'
Zurich_canton = read_html(url)
print('Data downloaded!')
# Out:
# Data downloaded!

# %%
Zurich_canton[2]
# Out:
#      Unnamed: 0            Place          Code       Country          Admin1  \
# 0           1.0          ZÃ¼rich          8001   Switzerland  Kanton ZÃ¼rich
# 1           NaN      47.367/8.55   47.367/8.55   47.367/8.55     47.367/8.55
# 2           2.0          ZÃ¼rich          8002   Switzerland  Kanton ZÃ¼rich
# 3           NaN      47.367/8.55   47.367/8.55   47.367/8.55     47.367/8.55
# 4           3.0          ZÃ¼rich          8003   Switzerland  Kanton ZÃ¼rich
# ..          ...              ...           ...           ...             ...
# 396       199.0        Ebertswil          8925   Switzerland  Kanton ZÃ¼rich
# 397         NaN      47.226/8.55   47.226/8.55   47.226/8.55     47.226/8.55
# 398       200.0  Kappel am Albis          8926   Switzerland  Kanton ZÃ¼rich
# 399         NaN     47.228/8.527  47.228/8.527  47.228/8.527    47.228/8.527
# 400         NaN              NaN           NaN           NaN             NaN
#
#                Admin2           Admin3
# 0      Bezirk ZÃ¼rich          ZÃ¼rich
# 1         47.367/8.55      47.367/8.55
# 2      Bezirk ZÃ¼rich          ZÃ¼rich
# 3         47.367/8.55      47.367/8.55
# 4      Bezirk ZÃ¼rich          ZÃ¼rich
# ..                ...              ...
# 396  Bezirk Affoltern  Hausen am Albis
# 397       47.226/8.55      47.226/8.55
# 398  Bezirk Affoltern  Kappel am Albis
# 399      47.228/8.527     47.228/8.527
# 400               NaN              NaN
#
# [401 rows x 7 columns]

# %%
df_zurich_Canton = Zurich_canton[2]

# %%
df_zurich_Canton.iloc[::2]
# Out:
#      Unnamed: 0            Place  Code      Country          Admin1  \
# 0           1.0          ZÃ¼rich  8001  Switzerland  Kanton ZÃ¼rich
# 2           2.0          ZÃ¼rich  8002  Switzerland  Kanton ZÃ¼rich
# 4           3.0          ZÃ¼rich  8003  Switzerland  Kanton ZÃ¼rich
# 6           4.0          ZÃ¼rich  8004  Switzerland  Kanton ZÃ¼rich
# 8           5.0          ZÃ¼rich  8005  Switzerland  Kanton ZÃ¼rich
# ..          ...              ...   ...          ...             ...
# 392       197.0  Aeugst am Albis  8914  Switzerland  Kanton ZÃ¼rich
# 394       198.0  Hausen am Albis  8915  Switzerland  Kanton ZÃ¼rich
# 396       199.0        Ebertswil  8925  Switzerland  Kanton ZÃ¼rich
# 398       200.0  Kappel am Albis  8926  Switzerland  Kanton ZÃ¼rich
# 400         NaN              NaN   NaN          NaN             NaN
#
#                Admin2           Admin3
# 0      Bezirk ZÃ¼rich          ZÃ¼rich
# 2      Bezirk ZÃ¼rich          ZÃ¼rich
# 4      Bezirk ZÃ¼rich          ZÃ¼rich
# 6      Bezirk ZÃ¼rich          ZÃ¼rich
# 8      Bezirk ZÃ¼rich          ZÃ¼rich
# ..                ...              ...
# 392  Bezirk Affoltern  Aeugst am Albis
# 394  Bezirk Affoltern  Hausen am Albis
# 396  Bezirk Affoltern  Hausen am Albis
# 398  Bezirk Affoltern  Kappel am Albis
# 400               NaN              NaN
#
# [201 rows x 7 columns]

# %%
df_ZH_canton = df_zurich_Canton.iloc[::2]
df_ZH_canton
# Out:
#      Unnamed: 0            Place  Code      Country          Admin1  \
# 0           1.0          ZÃ¼rich  8001  Switzerland  Kanton ZÃ¼rich
# 2           2.0          ZÃ¼rich  8002  Switzerland  Kanton ZÃ¼rich
# 4           3.0          ZÃ¼rich  8003  Switzerland  Kanton ZÃ¼rich
# 6           4.0          ZÃ¼rich  8004  Switzerland  Kanton ZÃ¼rich
# 8           5.0          ZÃ¼rich  8005  Switzerland  Kanton ZÃ¼rich
# ..          ...              ...   ...          ...             ...
# 392       197.0  Aeugst am Albis  8914  Switzerland  Kanton ZÃ¼rich
# 394       198.0  Hausen am Albis  8915  Switzerland  Kanton ZÃ¼rich
# 396       199.0        Ebertswil  8925  Switzerland  Kanton ZÃ¼rich
# 398       200.0  Kappel am Albis  8926  Switzerland  Kanton ZÃ¼rich
# 400         NaN              NaN   NaN          NaN             NaN
#
#                Admin2           Admin3
# 0      Bezirk ZÃ¼rich          ZÃ¼rich
# 2      Bezirk ZÃ¼rich          ZÃ¼rich
# 4      Bezirk ZÃ¼rich          ZÃ¼rich
# 6      Bezirk ZÃ¼rich          ZÃ¼rich
# 8      Bezirk ZÃ¼rich          ZÃ¼rich
# ..                ...              ...
# 392  Bezirk Affoltern  Aeugst am Albis
# 394  Bezirk Affoltern  Hausen am Albis
# 396  Bezirk Affoltern  Hausen am Albis
# 398  Bezirk Affoltern  Kappel am Albis
# 400               NaN              NaN
#
# [201 rows x 7 columns]

# %%
# !pip install geocoder
import geocoder
# Out:
# Requirement already satisfied: geocoder in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (1.38.1)
# Requirement already satisfied: click in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (7.1.2)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (2.25.1)
# Requirement already satisfied: ratelim in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (1.15.0)
# Requirement already satisfied: future in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (0.18.2)
# Requirement already satisfied: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (4.0.0)
# Requirement already satisfied: decorator in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ratelim->geocoder) (4.4.2)

# %%
# Define latitude and longitude as lists.
latitude = []
longitude = []

# Loop through the City_State_Postal_Code data in the dataframe and for each postal code loop until coordicates are obtained.
for Code in df_ZH_canton['Code']:
    g = geocoder.arcgis(Code)
    print(Code, g.latlng)
    while(g.latlng is None):
        g = geocoder.arcgis(Code)
        print(Code, g.latlng)
    lat_lng_coords = g.latlng
    latitude.append(lat_lng_coords[0])
    longitude.append(lat_lng_coords[1])

df_ZH_canton['Latitude'] = latitude
df_ZH_canton['Longitude'] = longitude

df_ZH_canton
# Out:
# 8001 [39.55849500000005, -75.35896999999994]
# 8002 [39.942390000000046, -75.03218999999996]
# 8003 [39.90093150000007, -74.96151439999994]
# 8004 [39.76769000000007, -74.89097999999996]
# 8005 [39.77102510000003, -74.25766169999997]
# 8006 [39.75643500000007, -74.10825999999997]
# 8008 [39.56356000000005, -74.23974499999997]
# 8032 [39.782065000000046, -75.06427739699996]
# 8037 [39.63447000000008, -74.80602499999998]
# 8038 [39.50823280000003, -75.46115149999997]
# 8044 [39.76337500000005, 9.543418770000073]
# 8045 [39.868880700000034, -75.03791579999995]
# 8046 [40.01792500000005, -74.87969499999997]
# 8047 [39.683895000000064, 9.60137861100003]
# 8048 [39.97951500000005, -74.79789499999998]
# 8049 [39.85591500000004, -75.03513999999996]
# 8050 [39.72646000000003, -74.27838499999996]
# 8051 [39.79034500000006, -75.17560499999996]
# 8052 [39.95789000000008, -74.99921499999994]
# 8055 [39.86004500000007, -74.80268499999994]
# 8057 [39.96087470000003, -74.94728519999995]
# 8105 [39.944629500000076, -75.08741519999995]
# 8134 [50.65201015000008, 12.59365572400003]
# 8152 [47.07573778100004, 15.214892863000046]
# 8153 [47.161775000000034, 15.178273396000066]
# 8180 [42.29254300700006, 27.712294585000052]
# 8302 [39.42582500000003, -75.24349999999998]
# 8303 [41.67504500000007, 20.483060000000023]
# 8304 [50.49611120000003, 12.505592309000065]
# 8305 [41.724875000000054, 20.38313800000003]
# 8307 [41.78855500000003, 20.422393000000056]
# 8320 [39.389665000000036, -75.16216999999995]
# 8340 [39.43765500000006, -74.86000999999999]
# 8400 [49.35426462200007, 4.653665000000046]
# 8404 [39.30899000000005, -74.53130999999996]
# 8405 [39.362880000000075, -74.42637999999994]
# 8406 [39.34188500000005, -74.48192999999998]
# 8408 [47.507565000000056, 8.683199276000039]
# 8600 [50.10291550300008, 4.831965000000025]
# 8603 [40.21935000000008, -74.76163499999996]
# 8604 [40.21935000000008, -74.76163499999996]
# 8610 [40.20229500000005, -74.73436999999996]
# 8634 [47.677910000000054, 15.316977708000024]
# 8706 [42.31616500000007, 19.90078600000004]
# 8708 [47.25958000000003, 8.696614607000072]
# 8712 [47.41962500000005, 15.136679968000067]
# 8800 [49.90648500000003, 4.813853041000073]
# 8803 [40.52631000000008, -75.00621999999998]
# 8805 [40.56694500000003, -74.54434499999996]
# 8810 [40.38180180000006, -74.51460669999994]
# 8820 [40.56568000000004, -74.34252999999995]
# 8902 [40.46752150000003, -74.45587759999995]
# 8952 [47.49526000000003, 14.081888824000032]
# 8953 [47.38088861700004, 14.144430000000057]
# 8041 [40.03709420000007, -74.69778629999996]
# 8053 [39.89801500000004, -74.93870499999997]
# 8064 [39.95878000000005, -74.62844499999994]
# 8103 [39.93748000000005, -75.12017999999995]
# 8105 [39.944629500000076, -75.08741519999995]
# 8108 [39.91614920000006, -75.06926239999996]
# 8112 [50.66726200000005, 12.529087065000056]
# 8122 [47.24345500000004, 15.252765987000032]
# 8123 [42.46606181000004, 27.290770000000066]
# 8124 [47.24837250000007, 15.151702324000041]
# 8125 [42.63044250000007, 27.396611826000026]
# 8126 [47.335875000000044, 8.625548403000039]
# 8127 [42.60023650000005, 27.384612607000065]
# 8135 [47.266753347000076, 8.543825000000027]
# 8152 [47.07573778100004, 15.214892863000046]
# 8155 [42.40668271200008, 27.454225000000065]
# 8157 [42.27136450000006, 27.381688887000053]
# 8162 [47.28425469700005, 15.505025000000046]
# 8166 [42.05660750000004, 27.662412286000063]
# 8181 [47.16180250000008, 15.65688017900004]
# 8184 [47.27768000000003, 15.70507256600007]
# 8185 [47.48828000000003, 8.556158296000035]
# 8192 [47.41736281300007, 15.733532500000024]
# 8193 [47.56518500000004, 8.532430462000036]
# 8197 [47.61341500000003, 8.547100642000032]
# 8245 [39.177783600000055, -74.81912919999996]
# 8247 [39.049330000000054, -74.76221499999997]
# 8306 [41.76073000000008, 20.367499000000066]
# 8308 [41.81243500000005, 20.518323000000066]
# 8309 [50.47251385000004, 12.611939852000035]
# 8315 [39.27064000000007, -75.10144999999994]
# 8317 [39.405399800000055, -74.82801019999994]
# 8330 [39.44811000000004, -74.75411999999994]
# 8335 [42.315713619000064, 26.94582950000006]
# 8344 [39.55056470000005, -75.02334629999996]
# 8353 [39.45814500000006, -75.29829499999994]
# 8409 [47.50792800000005, 8.77871629200007]
# 8413 [46.865912458000025, 15.598897500000078]
# 8416 [47.58095000000003, 8.601193844000022]
# 8422 [46.80119597000004, 15.666280000000029]
# 8424 [46.792319880000036, 15.599195000000066]
# 8427 [50.69060700000006, 12.354465426000047]
# 8442 [46.778399500000035, 15.456400246000044]
# 8447 [42.84023846100007, 26.998078247000024]
# 8450 [49.60079500000006, 4.923014310000042]
# 8460 [49.71791500000006, 4.458256225000071]
# 8462 [46.71189000000004, 15.525466528000038]
# 8472 [46.73077500000005, 15.616206971000054]
# 8484 [46.735076038000045, 15.905652520000046]
# 8488 [42.57336500000008, 26.913341107000065]
# 8492 [46.72199000000006, 15.950035849000074]
# 8494 [47.369489000000044, 8.892239438000047]
# 8542 [40.35332000000005, -74.65926499999995]
# 8606 [40.21935000000008, -74.76163499999996]
# 8606 [40.21935000000008, -74.76163499999996]
# 8608 [40.22019000000006, -74.76509999999996]
# 8615 [-23.547422499999982, -46.296130981999966]
# 8617 [47.31075000000004, 8.716853317000073]
# 8618 [40.228645200000074, -74.76806349999998]
# 8625 [40.21788000000004, -74.75939999999997]
# 8627 [42.508630449000066, 26.599034690000053]
# 8630 [47.78493000000003, 15.309564333000026]
# 8632 [47.68409500000007, 15.165107589000058]
# 8635 [47.65083050000004, 15.303454499000054]
# 8636 [47.62007372000005, 15.271015000000034]
# 8700 [49.80831000000006, 4.819249064000076]
# 8702 [47.34143500000005, 8.578001025000049]
# 8704 [42.26126000000005, 20.08944500000007]
# 8707 [47.27107500000005, 8.683769743000028]
# 8713 [47.28052426600004, 15.030934174000038]
# 8802 [40.646340000000066, -75.00204499999995]
# 8804 [40.65537500000005, -75.08185499999996]
# 8816 [40.439432200000056, -74.39760389999998]
# 8833 [40.64403500000003, -74.83345999999995]
# 8906 [40.52058000000005, -74.41821499999998]
# 8907 [47.33666000000005, 8.471833423000021]
# 8908 [50.842895000000055, 2.8138839230000485]
# 8910 [47.278770000000065, 8.454456953000033]
# 8912 [47.52844806100006, 14.633727500000077]
# 8913 [47.617650000000026, 14.526030562000074]
# 8932 [47.70040000000006, 14.64626562500007]
# 8933 [40.49758490000005, -74.44175169999994]
# 8954 [47.49768250000005, 14.002099741000052]
# 8044 [39.76337500000005, 9.543418770000073]
# 8104 [39.92292500000008, -75.10832999999997]
# 8107 [39.90252000000004, -75.07867499999998]
# 8113 [47.088040000000035, 15.268015966000064]
# 8117 [42.51600550000006, 27.25583433500003]
# 8118 [50.66912680000007, 12.66979083900003]
# 8121 [47.21190000000007, 15.316136914000026]
# 8132 [50.73758895000003, 12.586997565000047]
# 8132 [50.73758895000003, 12.586997565000047]
# 8133 [47.28891500000003, 8.715949757000033]
# 8136 [47.28018400000008, 8.553238000000022]
# 8142 [46.929906000000074, 15.44130287300004]
# 8143 [46.92318477100008, 15.369337888000075]
# 8143 [46.92318477100008, 15.369337888000075]
# 8156 [47.46040700000003, 8.500839940000049]
# 8164 [42.00201800000008, 27.660215899000036]
# 8165 [42.03857400000004, 27.526296037000066]
# 8165 [42.03857400000004, 27.526296037000066]
# 8173 [42.16601700000007, 27.36942603600005]
# 8175 [47.547765500000025, 8.473108025000045]
# 8182 [47.225317500000074, 15.726481010000043]
# 8187 [47.554535000000044, 8.435250919000055]
# 8194 [47.59310000000005, 8.498244183000054]
# 8196 [47.60969000000006, 8.502070441000058]
# 8248 [39.19471500000003, -74.65932499999997]
# 8310 [39.51127980000007, -74.92335529999997]
# 8311 [39.337465000000066, -75.20370499999996]
# 8322 [39.616972400000066, -75.07658719999995]
# 8331 [42.24275350000005, 27.039873945000068]
# 8332 [39.39952000000005, -75.03356999999994]
# 8342 [39.486770000000035, -74.83583999999996]
# 8345 [39.294917600000076, -75.17606949999998]
# 8414 [47.54705500000006, 8.629092688000071]
# 8425 [47.48950000000008, 8.633836916000064]
# 8426 [47.48183000000006, 8.59473581800006]
# 8444 [46.79329716600006, 15.394452500000057]
# 8451 [50.81916220000005, 12.380092658000024]
# 8457 [42.876883434000035, 26.71525500000007]
# 8458 [42.876419000000055, 26.761884645000066]
# 8463 [46.66651000000007, 15.485890435000044]
# 8466 [42.73618150000004, 26.774729413000045]
# 8467 [42.69124685500003, 26.819733000000042]
# 8474 [42.599015500000064, 26.81812787100006]
# 8475 [42.47681176700007, 26.982327500000054]
# 8483 [46.76415000000003, 15.820528263000028]
# 8487 [42.605944220000026, 26.92847000000006]
# 8493 [46.78974516300008, 15.964830000000063]
# 8495 [47.418945000000065, 8.904410125000027]
# 8497 [47.332349469000064, 8.925006500000052]
# 8548 [50.55391995000008, 12.087964899000042]
# 8605 [40.21935000000008, -74.76163499999996]
# 8616 [47.383095000000026, 15.57602102800007]
# 8620 [40.18572150000006, -74.67910319999999]
# 8624 [47.58574355500008, 15.26963500000005]
# 8637 [42.46488850000003, 26.395315648000064]
# 8825 [40.53052000000008, -75.05907999999994]
# 8903 [40.49075000000005, -74.45334499999996]
# 8909 [47.28935000000007, 8.432614694000051]
# 8911 [47.588535000000036, 14.455969864000053]
# 8914 [42.60985000000005, 25.94801595900003]
# 8915 [42.578444500000046, 26.024073091000048]
# 8925 [47.22846100000004, 8.55358362100003]
# 8926 [47.22515000000004, 8.516513147000069]
# nan [18.776095734718467, 100.77393496701143]
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      Unnamed: 0            Place  Code      Country          Admin1  \
# 0           1.0          ZÃ¼rich  8001  Switzerland  Kanton ZÃ¼rich
# 2           2.0          ZÃ¼rich  8002  Switzerland  Kanton ZÃ¼rich
# 4           3.0          ZÃ¼rich  8003  Switzerland  Kanton ZÃ¼rich
# 6           4.0          ZÃ¼rich  8004  Switzerland  Kanton ZÃ¼rich
# 8           5.0          ZÃ¼rich  8005  Switzerland  Kanton ZÃ¼rich
# ..          ...              ...   ...          ...             ...
# 392       197.0  Aeugst am Albis  8914  Switzerland  Kanton ZÃ¼rich
# 394       198.0  Hausen am Albis  8915  Switzerland  Kanton ZÃ¼rich
# 396       199.0        Ebertswil  8925  Switzerland  Kanton ZÃ¼rich
# 398       200.0  Kappel am Albis  8926  Switzerland  Kanton ZÃ¼rich
# 400         NaN              NaN   NaN          NaN             NaN
#
#                Admin2           Admin3   Latitude   Longitude
# 0      Bezirk ZÃ¼rich          ZÃ¼rich  39.558495  -75.358970
# 2      Bezirk ZÃ¼rich          ZÃ¼rich  39.942390  -75.032190
# 4      Bezirk ZÃ¼rich          ZÃ¼rich  39.900932  -74.961514
# 6      Bezirk ZÃ¼rich          ZÃ¼rich  39.767690  -74.890980
# 8      Bezirk ZÃ¼rich          ZÃ¼rich  39.771025  -74.257662
# ..                ...              ...        ...         ...
# 392  Bezirk Affoltern  Aeugst am Albis  42.609850   25.948016
# 394  Bezirk Affoltern  Hausen am Albis  42.578445   26.024073
# 396  Bezirk Affoltern  Hausen am Albis  47.228461    8.553584
# 398  Bezirk Affoltern  Kappel am Albis  47.225150    8.516513
# 400               NaN              NaN  18.776096  100.773935
#
# [201 rows x 9 columns]

# %% [markdown]
# ##### Creating the function to get the near by resturants and Hotels

# %%
df_Canton = df_ZH_canton[['Place','Latitude','Longitude']]
df_Canton
# Out:
#                Place   Latitude   Longitude
# 0            ZÃ¼rich  39.558495  -75.358970
# 2            ZÃ¼rich  39.942390  -75.032190
# 4            ZÃ¼rich  39.900932  -74.961514
# 6            ZÃ¼rich  39.767690  -74.890980
# 8            ZÃ¼rich  39.771025  -74.257662
# ..               ...        ...         ...
# 392  Aeugst am Albis  42.609850   25.948016
# 394  Hausen am Albis  42.578445   26.024073
# 396        Ebertswil  47.228461    8.553584
# 398  Kappel am Albis  47.225150    8.516513
# 400              NaN  18.776096  100.773935
#
# [201 rows x 3 columns]

# %%
def getNearbySelectVenues(names, latitudes, longitudes):
    resturants_Category_id = '4bf58dd8d48988d142941735'
    hotel_Category_id = '4bf58dd8d48988d1fa931735'
    radius = 5000
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
        
    # create the API request URL for Resturants
        resturants_shop_url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT,
            resturants_Category_id)
            
            # make the get request
    resturants_results = requests.get(resturants_shop_url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby Resturants venue
    venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in resturants_results])
        
    Hotels_shop_url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT,
            hotel_Category_id)
        
    Hotels_results = requests.get(Hotels_shop_url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby Resturants venue
    venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in Hotels_results])
        
    nearby_select_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_select_venues.columns = ['Place',
                                    'Latitude',
                                    'Longitude',
                                    'Venue',
                                    'Venue_Latitude',
                                    'Venue_Longitude',
                                    'Venue_Category']
        
    return(nearby_select_venues)

# %%
df_Canton_select_venues = getNearbySelectVenues(names = df_Canton['Place'],
                                                latitudes = df_Canton['Latitude'],
                                                longitudes = df_Canton['Longitude'])
# Out:
# ZÃ¼rich
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-39-ad0721ffb774> in <module>
#       1 df_Canton_select_venues = getNearbySelectVenues(names = df_Canton['Place'],
#       2                                                 latitudes = df_Canton['Latitude'],
# ----> 3                                                 longitudes = df_Canton['Longitude'])
#
# <ipython-input-32-cc8ec6c02ae1> in getNearbySelectVenues(names, latitudes, longitudes)
#      16             radius,
#      17             LIMIT,
# ---> 18             resturants_Category_id)
#      19
#      20             # make the get request
#
# IndexError: tuple index out of range

# %%
# %debug
# Out:
# > <ipython-input-29-71fee8157d93>(18)getNearbySelectVenues()
#      16             radius,
#      17             LIMIT,
# ---> 18             resturants_Category_id)
#      19
#      20             # make the get request
#
# --KeyboardInterrupt--
